# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('6-11-chickpea-threshold-data-labeled-new.csv', sep='|')
df
# Out:
#      id  5_28PLNTCNT  _52344sum  _52344mean  52844_sum  52844_mean  60344_sum  \
# 0   101           99       6001    0.016285       1606    0.080437      34669
# 1   102           14        377    0.001023        122    0.006110       7561
# 2   103          116       5835    0.015835       1513    0.075790      40940
# 3   104          111       6104    0.016565       2114    0.105875      58997
# 4   105          135       7319    0.019862       2351    0.117756      61096
# 5   106          147       7237    0.019639       2111    0.105719      42018
# 6   107          143       4951    0.013436       1610    0.080633      35612
# 7   108          132       4506    0.012228       1410    0.070624      45506
# 8   109          101       4107    0.011145        991    0.049634      25871
# 9   201            7        134    0.000364         79    0.003957       3416
# 10  202          142       9788    0.026562       2325    0.116442      61685
# ...

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
sns.lmplot(x="_52344sum", y="6-13 average stand", data=df)
plt.show()

# %%
X = df[['_52344sum', "60344_sum", "61144_sum"]]
y = df['6-13 average stand']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=33)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train,y_train)
# Out:
# 0.6047941942078345

# %%
model.score(X_test,y_test)
# Out:
# -28.425971190678812

# %%
y_pred = model.predict(X_test)
y
# Out:
# 0      95.0
# 1      15.0
# 2      97.5
# 3      97.5
# 4      97.5
# 5      95.0
# 6      95.0
# 7      95.0
# 8      92.5
# 9      10.0
# 10     97.5
# 11     95.0
# 12     97.5
# 13     97.5
# 14     97.5
# 15    100.0
# 16     92.5
# 17     92.5
# 18     97.5
# 19     97.5
# 20    100.0
# 21    100.0
# 22    100.0
# 23     97.5
# 24     90.0
# 25     97.5
# 26     70.0
# Name: 6-13 average stand, dtype: float64

# %%
plt.scatter(X, y, color='darkorange', label='data') 
plt.plot(cvt, np.array(y), color='cornflowerblue', label='prediction') 
plt.legend() 
plt.show()
